# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./world-happiness-report-2019.csv')
df = data.copy()
df.sample(156)
# Out:
#     Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 10         Australia      11            26             47.0             37.0
# 110          Senegal     111            44             68.0             60.0
# 66          Pakistan      67            53            130.0            111.0
# 135           Uganda     136           148             91.0            139.0
# 82          Mongolia      83            48             95.0             17.0
# ..               ...     ...           ...              ...              ...
# 1            Denmark       2            13             24.0             26.0
# 142       Madagascar     143            77             46.0             96.0
# 118          Georgia     119            51            141.0             43.0
# 133         Ethiopia     134            38            100.0             74.0
# 139            India     140            41             93.0            115.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
# Country (region)           156 non-null object
# Ladder                     156 non-null int64
# SD of Ladder               156 non-null int64
# Positive affect            155 non-null float64
# Negative affect            155 non-null float64
# Social support             155 non-null float64
# Freedom                    155 non-null float64
# Corruption                 148 non-null float64
# Generosity                 155 non-null float64
# Log of GDP
# per capita      152 non-null float64
# Healthy life
# expectancy    150 non-null float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 13.5+ KB

# %%
df.rename(columns={'SD of Ladder':'Ranking'}, inplace = True)

# %%
print(str('NaN value in the dataset: '), df.isnull().values.any())
# Out:
# NaN value in the dataset:  True

# %%
df.isnull().sum()
# Out:
# Country (region)            0
# Ladder                      0
# Ranking                     0
# Positive affect             1
# Negative affect             1
# Social support              1
# Freedom                     1
# Corruption                  8
# Generosity                  1
# Log of GDP\nper capita      4
# Healthy life\nexpectancy    6
# dtype: int64

# %%
df.fillna(0, inplace = True)

# %%
print(str('NaN value in the dataset: '), df.isnull().values.any())
# Out:
# NaN value in the dataset:  False

# %%
df.sample(156)
# Out:
#             Country (region)  Ladder  Ranking  Positive affect  \
# 61                   Hungary      62       36             86.0
# 139                    India     140       41             93.0
# 77   Bosnia and Herzegovina       78       80            116.0
# 88                   Morocco      89      101            110.0
# 71                     Libya      72      115             85.0
# ..                       ...     ...      ...              ...
# 116                     Iran     117      109            109.0
# 2                     Norway       3        8             16.0
# 136                    Egypt     137       66            146.0
# 152                 Tanzania     153      122             78.0
# 96                  Bulgaria      97       47            117.0
#
#      Negative affect  Social support  Freedom  Corruption  Generosity  \
# 61              31.0            51.0    138.0       140.0       100.0
# ...

# %%
order =df.sort_values('Ranking')
order.head()
# Out:
#    Country (region)  Ladder  Ranking  Positive affect  Negative affect  \
# 4       Netherlands       5        1             12.0             25.0
# 86     Turkmenistan      87        2            135.0             63.0
# 13       Luxembourg      14        3             62.0             19.0
# 0           Finland       1        4             41.0             10.0
# 33        Singapore      34        5             38.0              2.0
#
#     Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 4             15.0     19.0        12.0         7.0                    12.0
# 86             8.0     83.0         0.0        33.0                    60.0
# 13            27.0     28.0         9.0        30.0                     2.0
# 0              2.0      5.0         4.0        47.0                    22.0
# 33            36.0     20.0         1.0        21.0                     3.0
#
#     Healthy life\nexpectancy
# 4                       18.0
# ...

# %%
df.isnull().sum()
# Out:
# Country (region)            0
# Ladder                      0
# Ranking                     0
# Positive affect             0
# Negative affect             0
# Social support              0
# Freedom                     0
# Corruption                  0
# Generosity                  0
# Log of GDP\nper capita      0
# Healthy life\nexpectancy    0
# dtype: int64

# %%
attributes = ['Negative affect','Social support','Log of GDP\nper capita','Healthy life\nexpectancy','Positive affect',
         'Freedom','Corruption','Generosity']
X = df[attributes]
y = df.Ranking

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(),ax=ax,annot=True,linewidth=0.05,fmt='.2f',cmap='magma')
plt.show()

# %%
sns.pairplot(data)
# Out:
# C:\Users\kavya\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\kavya\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plt.scatter(data['Positive affect'],data['Negative affect'])
plt.xlabel('positive affect', fontsize=15)
plt.ylabel('negative affect', fontsize=15)
plt.title('positive vs negative', fontsize=20)
plt.show()

# %%
plt.scatter(data['Social support'],data['Healthy life\nexpectancy'])
plt.xlabel('Social support',fontsize = 12)
plt.ylabel('Healthy life\nexpectancy',fontsize = 12)
plt.title('Social support vs Healthy life\nexpectancy', fontsize = 18)

corr = np.corrcoef(data['Social support'],data['Healthy life\nexpectancy'])[0,1]
print("correlation coefficeint:",corr)
# Out:
# correlation coefficeint: nan

# %%
plt.scatter(data['Log of GDP\nper capita'],data['Healthy life\nexpectancy'])
plt.xlabel('GDP',fontsize = 12)
plt.ylabel('Healthy life\nexpectancy',fontsize = 12)
plt.title('Log of GDP\nper capita vs Healthy life\nexpectancy', fontsize = 18)

corr = np.corrcoef(data['Log of GDP\nper capita'],data['Healthy life\nexpectancy'])[0,1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
print('X_train: ', np.shape(X_train))
print('y_train: ', np.shape(y_train))
print('X_test: ', np.shape(X_test))
print('y_test: ', np.shape(y_test))
# Out:
# X_train:  (124, 8)
# y_train:  (124,)
# X_test:  (32, 8)
# y_test:  (32,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import  r2_score

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Model intercept: ', reg.intercept_)
print('Model coefficients: ', reg.coef_)
# Out:
# Model intercept:  16.47068296024341
# Model coefficients:  [ 0.43948966  0.1757162   0.0737841   0.2136386  -0.32453981  0.00473234
#   0.12925191  0.10599874]

# %%
y_head = reg.predict(X_train)

# %%
r2_score(y_train, y_head)
# Out:
# 0.5979868640653649

# %%
from sklearn.model_selection import cross_val_score
cross_val_score_train = cross_val_score(reg, X_train, y_train, cv=10, scoring='r2')
print(cross_val_score_train)
# Out:
# [0.43845802 0.30325191 0.72726979 0.64736839 0.49332407 0.77668852
#  0.52786995 0.24989707 0.58660583 0.47099491]

# %%
cross_val_score_train.mean()
# Out:
# 0.5221728443960674

# %%
y_pred = reg.predict(X_test)

# %%
print(r2_score(y_test, y_pred))
# Out:
# 0.5332873046688128
